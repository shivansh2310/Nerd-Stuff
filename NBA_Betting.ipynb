# %% [markdown]
# <a href="https://colab.research.google.com/github/shivansh2310/Nerd-Stuff/blob/main/NBA_Betting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Remove Preexisting Files
! rm -rf NBA-Machine-Learning-Sports-Betting
! rm -rf *

#Bootstrap Files
! git clone https://github.com/kyleskom/NBA-Machine-Learning-Sports-Betting.git
! mv -v ./NBA-Machine-Learning-Sports-Betting/* .
! pip3 install -r requirements.txt

#Clear Bootstrap Logs
from IPython.display import clear_output 
clear_output()

print("Successful Bootstrap!!!")
# Out:
# Successful Bootstrap!!!

# %%
# !python3 main.py -A -odds=fanduel
# Out:
# 2023-04-05 16:48:37.840175: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 16:48:39.032263: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ------------------fanduel odds data------------------
# New York Knicks (-176) @ Indiana Pacers (148)
# Brooklyn Nets (-620) @ Detroit Pistons (460)
# Washington Wizards (490) @ Atlanta Hawks (-670)
# Toronto Raptors (152) @ Boston Celtics (-180)
# Chicago Bulls (220) @ Milwaukee Bucks (-270)
# Memphis Grizzlies (172) @ New Orleans Pelicans (-205)
# Sacramento Kings (205) @ Dallas Mavericks (-250)
# Los Angeles Lakers (140) @ LA Clippers (-166)
# ---------------XGBoost Model Predictions---------------
# ...

# %%
# !python3 main.py -A -odds=draftkings
# Out:
# 2023-04-05 17:13:51.093025: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 17:13:52.500892: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ------------------draftkings odds data------------------
# New York Knicks (-190) @ Indiana Pacers (160)
# Brooklyn Nets (-580) @ Detroit Pistons (440)
# Washington Wizards (400) @ Atlanta Hawks (-500)
# Toronto Raptors (125) @ Boston Celtics (-145)
# Chicago Bulls (230) @ Milwaukee Bucks (-275)
# Memphis Grizzlies (175) @ New Orleans Pelicans (-205)
# Sacramento Kings (210) @ Dallas Mavericks (-250)
# Los Angeles Lakers (135) @ LA Clippers (-155)
# ---------------XGBoost Model Predictions---------------
# ...

# %%
## Add Twitter Sentiment Analysis
import tweepy
from textblob import TextBlob

# Authenticate with Twitter API
consumer_key = 'eq9QvcZRupgT1iBdqEbnu9Wea'
consumer_secret = 'cvbu9YAI5TcGXkuVk6mNB54cNjlAo3Pbr3NcXGb109XFI2PcHX'
access_token = '2479063608-4cx5s5H6wIRXZJBcM19MbGSBBLPUCuY8K54UYNv'
access_token_secret = 'vpGBGHEzBrxNp1JKIeWSE9c1n5WMACamAeDVTcNFj8j8k'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# Search for tweets about the Warriors
warriors_tweets = tweepy.Cursor(api.search, q='#Brooklyn Nets').items(100)


# Perform sentiment analysis on tweets
positive_tweets = 0
negative_tweets = 0
neutral_tweets = 0

for tweet in warriors_tweets:
    analysis = TextBlob(tweet.text)
    if analysis.sentiment.polarity > 0:
        positive_tweets += 1
    elif analysis.sentiment.polarity < 0:
        negative_tweets += 1
    else:
        neutral_tweets += 1

# Print results
print("Positive tweets: ", positive_tweets)
print("Negative tweets: ", negative_tweets)
print("Neutral tweets: ", neutral_tweets)


##if positive_tweets > negative_tweets:
  # continue
  #else:
    ##say the opposing team will win

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 KB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 24.4 MB/s eta 0:00:00
# ...

# %%
## Add GPT Explanation


# Import the OpenAI library
import openai

# Set the API key
openai.api_key = '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'

# Define the text to summarize
text = """
------------------fanduel odds data------------------
New York Knicks (-176) @ Indiana Pacers (148)
Brooklyn Nets (-620) @ Detroit Pistons (460)
Washington Wizards (490) @ Atlanta Hawks (-670)
Toronto Raptors (152) @ Boston Celtics (-180)
Chicago Bulls (220) @ Milwaukee Bucks (-270)
Memphis Grizzlies (172) @ New Orleans Pelicans (-205)
Sacramento Kings (205) @ Dallas Mavericks (-250)
Los Angeles Lakers (140) @ LA Clippers (-166)
---------------XGBoost Model Predictions---------------
Indiana Pacers vs New York Knicks (62.7%): OVER 229 (53.0%)
Detroit Pistons vs Brooklyn Nets (71.2%): UNDER 218 (54.4%)
Atlanta Hawks (60.6%) vs Washington Wizards: UNDER 234 (54.5%)
Boston Celtics (80.9%) vs Toronto Raptors: OVER 223.5 (73.2%)
Milwaukee Bucks (72.0%) vs Chicago Bulls: UNDER 229.5 (51.3%)
New Orleans Pelicans (54.8%) vs Memphis Grizzlies: UNDER 229.5 (51.9%)
Dallas Mavericks vs Sacramento Kings (58.0%): UNDER 241.5 (73.5%)
LA Clippers (59.1%) vs Los Angeles Lakers: UNDER 232 (53.2%)
--------------------Expected Value---------------------
Indiana Pacers EV: -7.46
New York Knicks EV: -1.7
Detroit Pistons EV: 61.1
Brooklyn Nets EV: -17.28
Atlanta Hawks EV: -30.34
Washington Wizards EV: 132.38
Boston Celtics EV: 25.88
Toronto Raptors EV: -51.93
Milwaukee Bucks EV: -1.37
Chicago Bulls EV: -10.32
New Orleans Pelicans EV: -18.5
Memphis Grizzlies EV: 23.0
Dallas Mavericks EV: -41.16
Sacramento Kings EV: 76.82
LA Clippers EV: -5.25
Los Angeles Lakers EV: -1.9
-------------------------------------------------------
------------Neural Network Model Predictions-----------
Indiana Pacers vs New York Knicks (62.0%): OVER 229 (50.3%)
Detroit Pistons vs Brooklyn Nets (75.6%): OVER 218 (50.0%)
Atlanta Hawks (69.6%) vs Washington Wizards: UNDER 234 (51.1%)
Boston Celtics (82.1%) vs Toronto Raptors: UNDER 223.5 (49.9%)
Milwaukee Bucks (79.7%) vs Chicago Bulls: UNDER 229.5 (53.6%)
New Orleans Pelicans (55.0%) vs Memphis Grizzlies: OVER 229.5 (50.7%)
Dallas Mavericks vs Sacramento Kings (57.2%): UNDER 241.5 (53.5%)
LA Clippers (63.6%) vs Los Angeles Lakers: UNDER 232 (51.7%)
--------------------Expected Value---------------------
Indiana Pacers EV: -5.78
New York Knicks EV: -2.76
Detroit Pistons EV: 36.79
Brooklyn Nets EV: -12.24
Atlanta Hawks EV: -20.04
Washington Wizards EV: 79.49
Boston Celtics EV: 27.7
Toronto Raptors EV: -54.88
Milwaukee Bucks EV: 9.26
Chicago Bulls EV: -35.14
New Orleans Pelicans EV: -18.12
Memphis Grizzlies EV: 22.31
Dallas Mavericks EV: -40.14
Sacramento Kings EV: 74.58
LA Clippers EV: 1.9
Los Angeles Lakers EV: -12.63
-------------------------------------------------------
"""

# Use the OpenAI API to summarize the text
response = openai.Completion.create(
    engine="text-davinci-002",
    prompt=(f"tell me the winners and losers: {text}"),
    max_tokens=500
)

# Print the summary
print(response["choices"][0]["text"])
